# %% [markdown]
# <a href="https://colab.research.google.com/github/inefable12/upch_rp_2023/blob/main/La_maldicion_de_la_dimensionalidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # La maldición de la dimensionalidad

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randint(10, size=10)
y = np.random.randint(10, size=10)
z = np.random.randint(10, size=10)
x,y,z
# Out:
# (array([8, 6, 3, 4, 6, 9, 3, 0, 5, 3]),
#  array([7, 2, 8, 6, 5, 4, 9, 2, 9, 5]),
#  array([9, 8, 0, 3, 8, 2, 3, 7, 2, 5]))

# %%
fig = plt.figure(figsize=(18,6))

#espacio unidimensinonal
ax = fig.add_subplot(1,3,1)
ax.plot(x, [0]*10, linewidth=0,marker='*',
        color="purple",markersize=20)

#espacio bidimensional
ax = fig.add_subplot(1,3,2)
ax.scatter(x, y, marker='*',
        c="purple",s=200)

#espacio tridimensional
ax = fig.add_subplot(1,3,3, projection="3d")
ax.scatter(x, y, z, marker='*',
        c="purple",s=200)

plt.show()

# %%
fig = plt.figure(figsize=(18,6))

#espacio unidimensinonal
ax = fig.add_subplot(1,3,1)
ax.set_title("10E1 = 10", fontsize=35)

ax.plot(range(0,10), [0]*10,
        marker="o",linewidth=0,
        color="skyblue",markersize=20)

ax.plot(x, [0]*10, linewidth=0,marker='*',
        color="purple",markersize=20)

#espacio bidimensional
ax = fig.add_subplot(1,3,2)

ax.set_title("10E2 = 100", fontsize=35)

for i in range(10):
  ax.scatter(range(0,10), [i]*10, marker='*',
        c="skyblue",s=200)

ax.scatter(x,y, marker="*",c="purple",s=200)

#espacio tridimensional
ax = fig.add_subplot(1,3,3, projection="3d")

ax.set_title("10E3 = 1000",fontsize=35)

for i in range(10):
  for j in range(10):
    ax.scatter(range(0,10), [i]*10,j,
               marker='*',c="skyblue",
               s=200,alpha=0.25)

ax.scatter(x,y,z, marker="*",c="purple",s=200)

plt.show()
